# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train=pd.read_csv('train.csv')

# %%
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
df_train.shape
# Out:
# (158106, 12)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
df_test=pd.read_csv('test.csv')

# %%
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             1.0                 1.0
# 1                          0             0.0                 3.0
# 2                         4+             1.0                 5.0
# 3                         4+             1.0                 4.0
# 4                          1             0.0                 4.0
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %%
df = pd.concat([df_train, df_test], ignore_index=True)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 783662  1006036  P00118942      F  26-35          15             B
# 783663  1006036  P00254642      F  26-35          15             B
# 783664  1006036  P00031842      F  26-35          15             B
# 783665  1006037  P00124742      F  46-50           1             C
# 783666  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 783662                         4+               1                   8
# 783663                         4+               1                   5
# 783664                         4+               1                   1
# 783665                         4+               0                  10
# 783666                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN    8370.0
# 1                      6.0                14.0   15200.0
# 2                      NaN                 NaN    1422.0
# 3                     14.0                 NaN    1057.0
# 4                      NaN                 NaN    7969.0
# ...                    ...                 ...       ...
# 783662                 NaN                 NaN       NaN
# 783663                 8.0                 NaN       NaN
# 783664                 5.0                12.0       NaN
# 783665                16.0                 NaN       NaN
# 783666                 5.0                 NaN       NaN
#
# [783667 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 71.7+ MB

# %%
df.drop(['User_ID'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17        10.0             A
# 1  P00248942      F  0-17        10.0             A
# 2  P00087842      F  0-17        10.0             A
# 3  P00085442      F  0-17        10.0             A
# 4  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
pd.get_dummies(df['Gender'])
# Out:
#             F      M
# 0        True  False
# 1        True  False
# 2        True  False
# 3        True  False
# 4       False   True
# ...       ...    ...
# 237596  False   True
# 237597  False   True
# 237598  False   True
# 237599   True  False
# 237600  False  False
#
# [237601 rows x 2 columns]

# %%
##Handling categorical feature Gender
df['Gender']=df['Gender'].map({'F':0,'M':1,np.nan:1})

# %%
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17        10.0             A
# 1  P00248942       0  0-17        10.0             A
# 2  P00087842       0  0-17        10.0             A
# 3  P00085442       0  0-17        10.0             A
# 4  P00285442       1   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
##Handle categorical feature Age
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25', '26-'],
#       dtype=object)

# %%
df['Age']=df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7,np.nan:1})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
##fixing categorical City_category
# df_city=pd.get_dummies(df['City_Category'],drop_first=True)

# %%
df['City_Category']=df['City_Category'].map({'A':1,'B':2,'C':3,np.nan:1})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    1          10              1
# 1  P00248942       0    1          10              1
# 2  P00087842       0    1          10              1
# 3  P00085442       0    1          10              1
# 4  P00285442       1    7          16              3
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 8.0                16.0    1422.0
# 3                14.0                16.0    1057.0
# 4                 8.0                16.0    7969.0

# %%
df['Gender'].unique()
# Out:
# array([0, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237601 entries, 0 to 237600
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  237601 non-null  object
#  1   Gender                      237601 non-null  int64
#  2   Age                         237601 non-null  int64
#  3   Occupation                  237600 non-null  float64
#  4   City_Category               237601 non-null  int64
#  5   Stay_In_Current_City_Years  237600 non-null  object
#  6   Marital_Status              237600 non-null  float64
#  7   Product_Category_1          237600 non-null  float64
#  8   Product_Category_2          163883 non-null  float64
#  9   Product_Category_3          72441 non-null   float64
#  10  Purchase                    135528 non-null  float64
# dtypes: float64(6), int64(3), object(2)
# memory usage: 19.9+ MB

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         1
# City_Category                      0
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             73718
# Product_Category_3            165160
# Purchase                      102073
# dtype: int64

# %%
df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df['Product_Category_2'].value_counts()
# Out:
# Product_Category_2
# 8.0     17470
# 14.0    15271
# 2.0     13678
# 16.0    11914
# 15.0    10322
# 5.0      7113
# 4.0      7057
# 6.0      4540
# 11.0     3833
# 17.0     3750
# 13.0     2869
# 9.0      1594
# 12.0     1455
# 10.0      876
# 18.0      818
# 3.0       787
# 7.0       158
# Name: count, dtype: int64

# %%
#Replace the missing value with mode
df['Product_Category_2']=df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
df['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df['Product_Category_3'].mode()[0]
# Out:
# 16.0

# %%
df['Product_Category_3']=df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df['Product_Category_3'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    1          10              1
# 1  P00248942       0    1          10              1
# 2  P00087842       0    1          10              1
# 3  P00085442       0    1          10              1
# 4  P00285442       1    7          16              3
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 8.0                16.0    1422.0
# 3                14.0                16.0    1057.0
# 4                 8.0                16.0    7969.0

# %%
df.shape
# Out:
# (150187, 11)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    1          10              1
# 1  P00248942       0    1          10              1
# 2  P00087842       0    1          10              1
# 3  P00085442       0    1          10              1
# 4  P00285442       1    7          16              3
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                          4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 8.0                16.0    1422.0
# 3                14.0                16.0    1057.0
# 4                 8.0                16.0    7969.0

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4', '3', '1', '0', nan], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].fillna(df['Stay_In_Current_City_Years'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150187 entries, 0 to 150186
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  150187 non-null  object
#  1   Gender                      150187 non-null  int64
#  2   Age                         1 non-null       float64
#  3   Occupation                  150186 non-null  float64
#  4   City_Category               150187 non-null  int64
#  5   Stay_In_Current_City_Years  150187 non-null  object
#  6   Marital_Status              150185 non-null  float64
#  7   Product_Category_1          150185 non-null  float64
#  8   Product_Category_2          150187 non-null  float64
#  9   Product_Category_3          150187 non-null  float64
#  10  Purchase                    22588 non-null   float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 12.6+ MB

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype(int)

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(5,4))
sns.pairplot(df)

# %%
sns.barplot(x='Age',y='Purchase',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# ## **Observation**
# Purchasing of men is high then women

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Occupation',y='Purchase',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product_Category_1',y='Purchase',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product_Category_2',y='Purchase',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product_Category_3',y='Purchase',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
df_test=df[df['Purchase'].isnull()]

# %%
df_train=df[~df['Purchase'].isnull()]

# %% [markdown]
# ## Feature Scaling

# %%
X=df_train.drop('Purchase',axis=1)

# %%
X.shape
# Out:
# (550068, 10)

# %%
X.head()
# Out:
#   Product_ID  Gender  Age  Occupation  City_Category  \
# 0  P00069042       0    1        10.0              1
# 1  P00248942       0    1        10.0              1
# 2  P00087842       0    1        10.0              1
# 3  P00085442       0    1        10.0              1
# 4  P00285442       1    7        16.0              3
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2             0.0                 3.0
# 1                           2             0.0                 1.0
# 2                           2             0.0                12.0
# 3                           2             0.0                12.0
# 4                           4             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 8.0                16.0    1422.0
# 3                14.0                16.0    1057.0
# 4                 8.0                16.0    7969.0

# %%
Y=df_train['Purchase']
Y
# Out:
# 0          8370.0
# 1         15200.0
# 2          1422.0
# 3          1057.0
# 4          7969.0
#            ...
# 550063      368.0
# 550064      371.0
# 550065      137.0
# 550066      365.0
# 550067      490.0
# Name: Purchase, Length: 550068, dtype: float64

# %%
Y.shape
# Out:
# (550068,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=42)

# %% [markdown]
# **X:** Your feature data (all columns except 'Purchase').
#
# **Y:** Your target variable ('Purchase').
#
# **test_size=0.33:** This means 33% of the data will be used for testing, and the remaining 67% for training.
#
# **random_state=42:** This ensures that the split is reproducible. You'll get the same split every time you run the code with the same random state.
#
# The function returns four variables:
#
# **X_train:** Training features
#
# **X_test:** Testing features
#
# **Y_train:** bold text Training target values
#
# **Y_test:** Testing target values

# %%
X_train.drop('Product_ID',axis=1,inplace=True)
X_test.drop('Product_ID',axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
